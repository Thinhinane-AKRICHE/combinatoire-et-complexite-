# %%
import numpy as np
import matplotlib.pyplot as plt 
import random as rd

# %%
N = 5
k = 0
T0 = 40
tau = 1e4
beta = 1e-1

# %%
#calcul de la fonction cout

def function_cout():
    global chemin
    xy = np.concatenate ((x[chemin],y[chemin]))
    print(x)
    print(y)
    print(xy)
    energie = np.sum(np.sqrt(xy - np.roll(xy, -1, axis=0))**22, 0)
    return energie

# %%
#choix du chemin initial 

x = np.random.uniform(0,1, N)
y = np.random.uniform(0,1, N)
chemin = np.arange(N)
cout = function_cout()
print("k= ",k,"chemin hamiltonien: ", chemin)
print("cout du chemin = Distance du chemin: ", cout)

while(k<N):
    plt.plot(x,y,x[chemin],y[chemin],marker='o',color='r')
    k+=1
# Out:
# k=  0 chemin hamiltonien:  [0 1 2 3 4]
# cout du chemin = Distance du chemin:  nan
# C:\Users\akric\AppData\Local\Temp\ipykernel_22280\3654849482.py:6: RuntimeWarning: invalid value encountered in sqrt
#   energie = np.sum(np.sqrt(xy - np.roll(xy, -1, axis=0))**22, 0)
